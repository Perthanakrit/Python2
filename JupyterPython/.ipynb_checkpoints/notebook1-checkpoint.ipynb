# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_data = [1.0, 1.8, 3.0, 4.1, 5.2, 6.0]
y_data = [1, 1.3, 2.2, 2.5, 2.8, 3.6]

x = np.array(x_data)
y = np.array(y_data)

# %% [markdown]
# Data Visualization

# %%
plt.scatter(x, y)
plt.grid()
plt.show()

# %%
x = x.reshape(-1,1)
x
